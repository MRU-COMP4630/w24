# %% [markdown]
# # Pandas Exercises
#
# Curated and edited by Yasaman Amannejad, edited by Charlotte Curtis.
#
# Time to test your pandas skills! Use the given csv file to complete the tasks in bold below.
#
# I recommend setting up a virtual environment, activating it, then installing the requirements. You can do this by running the following commands in your terminal:
#
# ```bash
# python3 -m venv venv
# source venv/bin/activate # or venv\Scripts\activate on Windows
# pip install -r requirements.txt
# ```
#
# You can also use [Google Colab](https://colab.research.google.com) if you don't want to set up a local environment.

# %% [markdown]
# **Import pandas and read in the studentlist.csv file into a dataframe called students.**

# %% [markdown]
# **Show the head of the dataframe**

# %% [markdown]
# **What are the column names?**

# %% [markdown]
# **How many Fjobs are represented in this data set?**

# %% [markdown]
# **What are the Fjobs represented in this data set?**

# %% [markdown]
# **How many rows of each Fjobs are represented in this data set?**

# %% [markdown]
# **What are the top 3 most popular jobs?**

# %% [markdown]
# **What are the top 3 most popular jobs among female students?**

# %% [markdown]
# **Show students study time and travel time with famsize of LE3**

# %% [markdown]
# **How many students have health index larger than 3?**

# %% [markdown]
# **For how many students are we missing the health indexes?**

# %% [markdown]
# **If a student had more than 5 absences, they should immediately fail the course. Calculate the passed column based on this rule.**

# %% [markdown]
# **Save the data with just the passing students in a new CSV file**

# %% [markdown]
# **Questions**
#
#
# 1.   If you were to fill in the missing values in the health column, what approaches would you use?
#
# 2.   If you were to divide the data into train and test data what considerations would you make?

# %% [markdown]
# ## Finding your own datasets
#
# In this course, you'll be expected to find and explore your own datasets. Think about:
# - What kind of data do you want to work with? For now, I recommend finding a numeric/categorical dataset rather than text, images, or time series.
# - What topics interest you? This could be anything - sports, cars, meteorology, movies, video games...
# - What questions do you want to answer?
#
# Data is everywhere, and many sources are publicly available. Here are some places to look for data:
# - [Kaggle](https://www.kaggle.com/datasets) - a website for machine learning competitions with a huge number of datasets. You can filter by file size, topic and more
# - [Papers with Code](https://paperswithcode.com/datasets) - pretty much what it says on the tin.
# - [UCI Machine Learning Repository](https://archive.ics.uci.edu/datasets) - a well-curated collection of datasets for learning purposes.
# - [Google Dataset Search](https://datasetsearch.research.google.com/) - of course Google does datasets as well.
#
# There's also some sources closer to home, but they're more challenging to navigate:
# - [City of Calgary Open data](https://data.calgary.ca/)
# - [Alberta Open Data](https://open.alberta.ca/opendata)
# - [Government of Canada Open Data](https://open.canada.ca/en/open-data)
#
# Try downloading a dataset (I recommend sticking to below ~10MB for now) and exploring it with pandas as above.
